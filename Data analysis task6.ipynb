# %%
import pandas as pd
#loading dataset
file_path= r"C:\Users\LENOVO\Desktop\disney_plus_titles.csv"
df=pd.read_csv(file_path)
#Data inspection 
print("\n Head details")
print(df.head())
print("\n Column names")
print(df.columns)
# Out:
#  Head details
#   show_id     type                           title  \
# 0      s1    Movie                   A Spark Story
# 1      s2    Movie                  Spooky Buddies
# 2      s3    Movie          The Fault in Our Stars
# 3      s4  TV Show                 Dog: Impossible
# 4      s5  TV Show  Spidey And His Amazing Friends
#
#                      director  \
# 0  Jason Sterman, Leanne Dare
# 1                Robert Vince
# 2                  Josh Boone
# 3                         NaN
# 4                         NaN
#
#                                                 cast                country  \
# 0                      Apthon Corbin, Louis Gonzales                    NaN
# 1  Tucker Albrizzi, Diedrich Bader, Ameko Eks Mas...  United States, Canada
# 2  Shailene Woodley, Ansel Elgort, Laura Dern, Sa...          United States
# 3                                       Matt Beisner          United States
# ...

# %%
import numpy as np

print("Initial dataset information:")
print(df.info())
print(df.describe())

# Handling missing data
#  Drop rows with missing values
df_cleaned = df.dropna()
# Out:
# Initial dataset information:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1368 entries, 0 to 1367
# Data columns (total 12 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   show_id       1368 non-null   object
#  1   type          1368 non-null   object
#  2   title         1368 non-null   object
#  3   director      928 non-null    object
#  4   cast          1194 non-null   object
#  5   country       1193 non-null   object
#  6   date_added    1365 non-null   object
#  7   release_year  1368 non-null   int64
#  8   rating        1366 non-null   object
#  9   duration      1368 non-null   object
#  10  listed_in     1368 non-null   object
#  11  description   1368 non-null   object
# dtypes: int64(1), object(11)
# memory usage: 128.4+ KB
# None
#        release_year
# count   1368.000000
# mean    2002.348684
# std       22.127559
# min     1928.000000
# 25%     1998.000000
# 50%     2011.000000
# 75%     2018.000000
# ...

# %%
#Data inspection after cleaning
print("\n Head details")
print(df_cleaned.head())
print("\n Column names")
print(df_cleaned.columns)
print("Initial dataset information:")
print(df_cleaned.info())
print(df_cleaned.describe())
# Out:
#  Head details
#    show_id   type                                        title       director  \
# 1       s2  Movie                               Spooky Buddies   Robert Vince
# 2       s3  Movie                       The Fault in Our Stars     Josh Boone
# 6       s7  Movie                  Confessions of a Shopaholic     P.J. Hogan
# 18     s19  Movie  Pirates of the Caribbean: On Stranger Tides   Rob Marshall
# 19     s20  Movie                             Twenty Something  Aphton Corbin
#
#                                                  cast  \
# 1   Tucker Albrizzi, Diedrich Bader, Ameko Eks Mas...
# 2   Shailene Woodley, Ansel Elgort, Laura Dern, Sa...
# 6   Isla Fisher, Hugh Dancy, Joan Cusack, John Goo...
# 18  Johnny Depp, Penélope Cruz, Ian McShane, Geoff...
# 19  Kaylin Price, Ariana Brown, Aliyah Taylor, Jan...
#
#                           country date_added  release_year rating duration  \
# 1           United States, Canada  24-Sep-21          2011      G   93 min
# ...

# %%
#1 What are the top 5 most frequent genres?
# Count the frequency of each genre
import pandas as pd
#loading dataset
file_path= r"C:\Users\LENOVO\Desktop\disney_plus_titles.csv"
df=pd.read_csv(file_path)
top_genres = df['listed_in'].value_counts().head(5)
print("Top 5 most frequent genres:")
print(top_genres)
# Out:
# Top 5 most frequent genres:
# listed_in
# Animation, Comedy, Family                120
# Action-Adventure, Animation, Comedy       75
# Action-Adventure, Animation, Kids         45
# Animals & Nature, Documentary, Family     40
# Action-Adventure, Animation, Family       40
# Name: count, dtype: int64

# %%
 #2.What is the distribution of ratings across all titles?
# Count the distribution of ratings
rating_distribution = df['rating'].value_counts()
print("Rating distribution:")
print(rating_distribution)
# Out:
# Rating distribution:
# rating
# TV-G        307
# TV-PG       275
# G           235
# PG          227
# TV-Y7       130
# TV-14        72
# PG-13        60
# TV-Y         48
# TV-Y7-FV     12
# Name: count, dtype: int64

# %%
#3.What is the most frequent release year for titles?
most_common_year = df['release_year'].mode()[0]
print(f"The most frequent release year: {most_common_year}")
# Out:
# The most frequent release year: 2020

# %%
#4.What percentage of content is TV shows vs Movies?
content_type_counts = df['type'].value_counts(normalize=True) * 100
print("Percentage of content type (TV Shows vs Movies):")
print(content_type_counts)
# Out:
# Percentage of content type (TV Shows vs Movies):
# type
# Movie      72.44152
# TV Show    27.55848
# Name: proportion, dtype: float64

# %%
#5.Which production countries have the most titles on Disney Plus?
# Assuming the column for country is 'country'
top_countries = df['country'].value_counts().head(10)
print("Top 10 countries with the most titles:")
print(top_countries)
# Out:
# Top 10 countries with the most titles:
# country
# United States                    976
# United States, Canada             28
# United Kingdom                    23
# United States, United Kingdom     19
# Canada, United States             17
# United Kingdom, United States     14
# United States, Australia           7
# Canada                             5
# United States, France              4
# United States, Japan               4
# Name: count, dtype: int64

# %%
#6.What is the average runtime for movies vs TV shows?
# Separate movies and TV shows
movies = df[df['type'] == 'Movie']
tv_shows = df[df['type'] == 'TV Show']

# For movies, extract duration in minutes
movies['duration_minutes'] = movies['duration'].str.extract('(\d+)').astype(float)

# For TV shows, extract the number of seasons (in case it's available as "X Seasons")
tv_shows['seasons'] = tv_shows['duration'].str.extract('(\d+)').astype(float)

# Calculate the average runtime for Movies
average_movie_runtime = movies['duration_minutes'].mean()

# Calculate the average number of seasons for TV Shows
average_tv_show_seasons = tv_shows['seasons'].mean()

print("Average runtime for Movies (in minutes):", average_movie_runtime)
print("Average number of seasons for TV Shows:", average_tv_show_seasons)
# Out:
# Average runtime for Movies (in minutes): 73.08072653884965
# Average number of seasons for TV Shows: 2.1379310344827585
# C:\Users\LENOVO\AppData\Local\Temp\ipykernel_8556\1933069902.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   movies['duration_minutes'] = movies['duration'].str.extract('(\d+)').astype(float)
# C:\Users\LENOVO\AppData\Local\Temp\ipykernel_8556\1933069902.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# ...

# %%
#7 .Which directors have produced the most content on Disney Plus?
#This analysis finds the most prolific directors on the platform.
top_directors = df['director'].value_counts().head(10)
print("Top 10 directors with the most titles:")
print(top_directors)
# Out:
# Top 10 directors with the most titles:
# director
# Jack Hannah         17
# John Lasseter       16
# Paul Hoen           16
# Charles Nichols     12
# Robert Stevenson    12
# Bob Peterson        10
# Vincent McEveety    10
# Wilfred Jackson      9
# James Algar          9
# Kenny Ortega         9
# Name: count, dtype: int64

# %%
#8.Find the top most cast members
# Split the 'cast' column by commas and stack the resulting series
cast_series = df['cast'].dropna().str.split(', ').explode()

# Count the frequency of each cast member
top_10_cast = cast_series.value_counts().head(10)

# Display the top 10 most frequent cast members
print("Top 10 Most Frequent Cast Members:")
print(top_10_cast)
# Out:
# Top 10 Most Frequent Cast Members:
# cast
# Jim Cummings            32
# Walt Disney             18
# Larry the Cable Guy     17
# Keith Ferguson          16
# Bill Farmer             15
# Corey Burton            15
# Pinto Colvig            15
# Bob Peterson            15
# Jeff Bennett            15
# Tim Allen               14
# Name: count, dtype: int64

# %%
#9. Find the number of movies released for each year in the dataset?
# Filter the dataset to include only movies
movies = df[df['type'] == 'Movie']

# Group by 'release_year' and count the number of movies for each year
movies_by_year = movies.groupby('release_year').size()

# Sort the result by year (optional)
movies_by_year = movies_by_year.sort_index()

# Display the result
print("Number of movies released each year:")
print(movies_by_year)
# Out:
# Number of movies released each year:
# release_year
# 1928     1
# 1932     3
# 1933     3
# 1934     4
# 1935     4
#         ..
# 2017    32
# 2018    32
# 2019    60
# 2020    72
# 2021    42
# Length: 90, dtype: int64

# %%
#10.Find the number of movies released by top 10 countries 
# Filter the dataset to include only movies
movies = df[df['type'] == 'Movie']

# Group by 'country' and count the number of movies for each country
movies_by_country = movies.groupby('country').size()

# Sort the result in descending order to get the top 10 countries
top_10_countries = movies_by_country.sort_values(ascending=False).head(10)

# Display the top 10 countries with the number of movies released
print("Top 10 countries by the number of movies released:")
print(top_10_countries)
# Out:
# Top 10 countries by the number of movies released:
# country
# United States                               752
# United States, Canada                        23
# United States, United Kingdom                18
# Canada, United States                        16
# United Kingdom, United States                13
# United Kingdom                               11
# United States, Australia                      7
# United States, United Kingdom, Australia      4
# United States, France                         4
# United States, United Kingdom, Canada         3
# dtype: int64

# %%
#Explorartory Data Analysis
# Basic information about the dataset
print("Basic Info of Dataset:")
df.info()

# Display missing values in each column
print("\nMissing Values in Dataset:")
print(df.isnull().sum())
# Out:
# Basic Info of Dataset:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1368 entries, 0 to 1367
# Data columns (total 12 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   show_id       1368 non-null   object
#  1   type          1368 non-null   object
#  2   title         1368 non-null   object
#  3   director      928 non-null    object
#  4   cast          1194 non-null   object
#  5   country       1193 non-null   object
#  6   date_added    1365 non-null   object
#  7   release_year  1368 non-null   int64
#  8   rating        1366 non-null   object
#  9   duration      1368 non-null   object
#  10  listed_in     1368 non-null   object
#  11  description   1368 non-null   object
# dtypes: int64(1), object(11)
# memory usage: 128.4+ KB
#
# Missing Values in Dataset:
# show_id           0
# type              0
# title             0
# director        440
# cast            174
# country         175
# date_added        3
# ...

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# Check for missing values in the DataFrame
missing_values = df.isnull().sum()

# Visualize missing values using a heatmap
plt.figure(figsize=(10, 6))
sns.heatmap(df.isnull(), cbar=False, cmap='viridis', yticklabels=False)
plt.title('Missing Values Heatmap')
plt.show()
plt.tight_layout()

# Handle missing values by dropping rows with missing 'director' values
disney_data_cleaned = df.dropna(subset=['director'])

# %%
#distribution of Movies vs TV Shows
import matplotlib.pyplot as plt
import seaborn as sns

# Plot the distribution of Movies vs TV Shows
plt.figure(figsize=(7,5))
sns.countplot(data=df, x='type', palette='viridis')
plt.title('Distribution of Movies vs TV Shows')
plt.xlabel('Content Type')
plt.ylabel('Count')
plt.show()
# Out:
# C:\Users\LENOVO\AppData\Local\Temp\ipykernel_8556\1632571565.py:6: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(data=df, x='type', palette='viridis')

# %%
plt.figure(figsize=(7,5))
sns.countplot(data=df, x='type', hue='listed_in', palette='viridis')
plt.title('Distribution of Movies vs TV Shows')
plt.xlabel('Content Type')
plt.ylabel('Count')
plt.show()

# %%
# Distribution of release year:Plot the distribution of release year
plt.figure(figsize=(10,6))
sns.histplot(data=df, x='release_year', bins=30, kde=True, color='hotpink')
plt.title('Distribution of Release Year')
plt.xlabel('Release Year')
plt.ylabel('Count')
plt.show()

# %%
#Distribution of rating
# Plot the distribution of content rating
plt.figure(figsize=(10,6))
sns.countplot(data=df, x='rating', order=df['rating'].value_counts().index, palette='viridis')
plt.title('Distribution of Content Ratings')
plt.xlabel('Rating')
plt.ylabel('Count')
plt.xticks(rotation=45)
plt.show()
# Out:
# C:\Users\LENOVO\AppData\Local\Temp\ipykernel_8556\2695271912.py:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(data=df, x='rating', order=df['rating'].value_counts().index, palette='viridis')

# %%
# Extract genres for analysis
genres = df['listed_in'].str.split(', ', expand=True).stack()

# Plot the top 10 most common genres
plt.figure(figsize=(12,6))
genres.value_counts().head(10).plot(kind='bar', color='skyblue')
plt.title('Top 10 Most Common Genres')
plt.xlabel('Genre')
plt.ylabel('Count')
plt.xticks(rotation=45)
plt.show()

# %%
# Filter the dataset to include only movies
disney_data_movies = df[df['type'] == 'Movie']

# Extract the duration in minutes by using regular expressions to find digits
disney_data_movies['duration_minutes'] = disney_data_movies['duration'].str.extract('(\d+)').astype(float)

# Plot the distribution of movie durations
plt.figure(figsize=(10,6))
sns.histplot(data=disney_data_movies, x='duration_minutes', bins=30, kde=True, color='purple')
plt.title('Distribution of Movie Durations')
plt.xlabel('Duration (Minutes)')
plt.ylabel('Count')
plt.show()
# Out:
# C:\Users\LENOVO\AppData\Local\Temp\ipykernel_8556\2120820581.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   disney_data_movies['duration_minutes'] = disney_data_movies['duration'].str.extract('(\d+)').astype(float)

# %%
import matplotlib.pyplot as plt
import seaborn as sns

plt.figure(figsize=(14, 8))  # Increased figure size for more space
sns.countplot(data=df, x='release_year', hue='type', palette='Set1')
plt.title('Movies and TV Shows by Release Year')
plt.xlabel('Release Year')
plt.ylabel('Count')
plt.xticks(rotation=90)
plt.tight_layout()  # Adjust layout to prevent clipping
plt.show()
